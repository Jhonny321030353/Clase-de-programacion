# %%
a11=0
a12=0
a13=0
b11=0
b12=0
b13=0
c11=0
c12=0
c13=0

jugador1=input('Ingresa la casilla: ')
if(jugador1=="a11"):
  a11=1
if(jugador1=="a12"):
  a12=1
if(jugador1=="a13"):
  a13=1
if(jugador1=="b11"):
  b11=1
if(jugador1=="b12"):
  b12=1
if(jugador1=="b13"):
  b13=1
if(jugador1=="c11"):
  c11=1
if(jugador1=="c12"):
  c12=1
if(jugador1=="c13"):
  c13=1



jugador2=input('Ingresa la casilla: ')
if(jugador2=="a11"):
  a11=2
if(jugador2=="a12"):
  a12=2
if(jugador2=="a13"):
  a13=2
if(jugador2=="b11"):
  b11=2
if(jugador2=="b12"):
  b12=2
if(jugador2=="b13"):
  b13=2
if(jugador2=="c11"):
  c11=2
if(jugador2=="c12"):
  c12=2
if(jugador2=="c13"):
  c13=2

jugador1=input('Ingresa la casilla: ')
if(jugador1=="a11"):
  a11=1
if(jugador1=="a12"):
  a12=1
if(jugador1=="a13"):
  a13=1
if(jugador1=="b11"):
  b11=1
if(jugador1=="b12"):
  b12=1
if(jugador1=="b13"):
  b13=1
if(jugador1=="c11"):
  c11=1
if(jugador1=="c12"):
  c12=1
if(jugador1=="c13"):
  c13=1



jugador2=input('Ingresa la casilla: ')
if(jugador2=="a11"):
  a11=2
if(jugador2=="a12"):
  a12=2
if(jugador2=="a13"):
  a13=2
if(jugador2=="b11"):
  b11=2
if(jugador2=="b12"):
  b12=2
if(jugador2=="b13"):
  b13=2
if(jugador2=="c11"):
  c11=2
if(jugador2=="c12"):
  c12=2
if(jugador2=="c13"):
  c13=2

jugador1=input('Ingresa la casilla: ')
if(jugador1=="a11"):
  a11=1
if(jugador1=="a12"):
  a12=1
if(jugador1=="a13"):
  a13=1
if(jugador1=="b11"):
  b11=1
if(jugador1=="b12"):
  b12=1
if(jugador1=="b13"):
  b13=1
if(jugador1=="c11"):
  c11=1
if(jugador1=="c12"):
  c12=1
if(jugador1=="c13"):
  c13=1


if((a11==1) and (a12==1)and(a13==1)):
  print("Gana jugador 1")


jugador2=input('Ingresa la casilla: ')
if(jugador2=="a11"):
  a11=2
if(jugador2=="a12"):
  a12=2
if(jugador2=="a13"):
  a13=2
if(jugador2=="b11"):
  b11=2
if(jugador2=="b12"):
  b12=2
if(jugador2=="b13"):
  b13=2
if(jugador2=="c11"):
  c11=2
if(jugador2=="c12"):
  c12=2
if(jugador2=="c13"):
  c13=2

if((a11==1) and (a12==1)and(a13==1)):
  print("Gana jugador 1")
# Out:
# Ingresa la casilla: a12
# Ingresa la casilla: a1
# Ingresa la casilla: a2
# Ingresa la casilla: e2
